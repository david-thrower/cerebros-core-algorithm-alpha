# %% [markdown]
# ## GPT2 + Cerebros for Phishing email detection

# %% [markdown]
# Initialization

# %%
import tensorflow as tf
import tensorflow_text
from keras_nlp.models import GPT2Tokenizer, GPT2Preprocessor, GPT2Backbone
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Flatten
import pandas as pd
import numpy as np
from cerebros.simplecerebrosrandomsearch.simple_cerebros_random_search\
    import SimpleCerebrosRandomSearch
import pendulum
from cerebros.units.units import DenseUnit
from cerebros.denseautomlstructuralcomponent.dense_automl_structural_component\
    import zero_7_exp_decay, zero_95_exp_decay, simple_sigmoid
from ast import literal_eval
# Out:
# Using TensorFlow backend

# %%
#
# Load the email data
#
df = pd.read_csv("Phishing_Email.csv")
#
# Get the rows where 'Email Text' is a string, remove everything else
#
df = df[df['Email Text'].apply(lambda x: isinstance(x, str))]
#
# Reset the index
#
df.reset_index(drop=True, inplace=True)

# %%
#
# Binary label for email type: positive type is "phishing"
#
label_mapping = {"Safe Email": 0, "Phishing Email": 1}
df["Binary Label"] = df["Email Type"].map(label_mapping)
#
# Data and labels ready
#
X = df["Email Text"].to_numpy()
y = df["Binary Label"].to_numpy()
#
# Shuffle the data
#
X, y = shuffle(X, y)

# %%
# Train / test split : we give 65% of the data for *testing*
X_train, X_test, y_train, y_test = \
train_test_split(X, y, test_size=0.65, shuffle=False)

# %%
#
# Tensors for training data and labels
#
training_x   = [tf.constant(X_train)]
train_labels = [tf.constant(y_train)]
#
# Input and output shapes
#
INPUT_SHAPES  = [()]
OUTPUT_SHAPES = [1]

# %% [markdown]
# ### A custom GPT2 encoder layer for text embedding

# %%
class GPT2Layer(tf.keras.layers.Layer):

    def __init__(self, max_seq_length, **kwargs):
        #
        super(GPT2Layer, self).__init__(**kwargs)
        #
        # Load the GPT2 tokenizer, preprocessor and model
        self.tokenizer = GPT2Tokenizer.from_preset("gpt2_base_en")
        self.preprocessor = GPT2Preprocessor(self.tokenizer,
                                             sequence_length=max_seq_length)
        self.encoder   = GPT2Backbone.from_preset("gpt2_base_en")
        #
        # Set whether the GPT2 model's layers are trainable
        #self.encoder.trainable = False
        for layer in self.encoder.layers:
            layer.trainable = False
        #
        self.encoder.layers[-2].trainable = True
        #
        # Set the maximum sequence length for tokenization
        self.max_seq_length = max_seq_length

    def call(self, inputs):
        #
        # Output the GPT2 embedding
        prep = self.preprocessor([inputs])
        embedding  = self.encoder(prep)
        avg_pool = tf.reduce_mean(embedding, axis=1)
        #
        return avg_pool

    def get_config(self):
        #
        config = super(GPT2Layer, self).get_config()
        config.update({'max_seq_length': self.max_seq_length})
        #
        return config

    @classmethod
    def from_config(cls, config):
        #
        return cls(max_seq_length=config['max_seq_length'])

# %%
# GPT2 configurables
max_seq_length = 96

# Base model
input_layer = Input(shape=(), dtype=tf.string)
gpt2_layer = GPT2Layer(max_seq_length)(input_layer)
#output = Flatten()(gpt2_layer)
base_model = Model(inputs=input_layer, outputs=gpt2_layer)
base_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-nlp/models/gpt2_base_en/v1/vocab.json
# 1042301/1042301 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/keras-nlp/models/gpt2_base_en/v1/merges.txt
# 456318/456318 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/keras-nlp/models/gpt2_base_en/v1/model.h5
# 497986112/497986112 [==============================] - 4s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None,)]                 0
#
#  gpt2_layer (GPT2Layer)      (None, 768)               124439808
#
# =================================================================
# Total params: 124439808 (474.70 MB)
# Trainable params: 7087872 (27.04 MB)
# Non-trainable params: 117351936 (447.66 MB)
# _________________________________________________________________

# %% [markdown]
# ### Cerebros search for the best model

# %%
#
# Cerebros configurables
#
activation = 'swish'
predecessor_level_connection_affinity_factor_first = 2.0
predecessor_level_connection_affinity_factor_main = 0.97
max_consecutive_lateral_connections = 5
p_lateral_connection = 0.97
num_lateral_connection_tries_per_unit = 2
learning_rate = 0.001
epochs = 6  # [1, 100]
batch_size = 32
maximum_levels = 5  # [3,7]
maximum_units_per_level = 7  # [2,10]
maximum_neurons_per_unit = 6  # [2,20]

# %%
#
# Logging
#
TIME = pendulum.now(tz='America/New_York').__str__()[:16]\
    .replace('T', '_')\
    .replace(':', '_')\
    .replace('-', '_')
PROJECT_NAME = f'{TIME}_cerebros_auto_ml_phishing_email_test'

# %%
meta_trial_number = 42 # irrelevant unless in distributed training

# %%
cerebros_automl = SimpleCerebrosRandomSearch(
    unit_type=DenseUnit,
    input_shapes=INPUT_SHAPES,
    output_shapes=OUTPUT_SHAPES,
    training_data=training_x,
    labels=train_labels,
    validation_split=0.35,
    direction='maximize',
    metric_to_rank_by="val_binary_accuracy",
    minimum_levels=2,
    maximum_levels=maximum_levels,
    minimum_units_per_level=1,
    maximum_units_per_level=maximum_units_per_level,
    minimum_neurons_per_unit=1,
    maximum_neurons_per_unit=maximum_neurons_per_unit,
    activation=activation,
    final_activation='sigmoid',
    number_of_architecture_moities_to_try=2,
    number_of_tries_per_architecture_moity=1,
    minimum_skip_connection_depth=1,
    maximum_skip_connection_depth=7,
    predecessor_level_connection_affinity_factor_first=predecessor_level_connection_affinity_factor_first,
    predecessor_level_connection_affinity_factor_first_rounding_rule='ceil',
    predecessor_level_connection_affinity_factor_main=predecessor_level_connection_affinity_factor_main,
    predecessor_level_connection_affinity_factor_main_rounding_rule='ceil',
    predecessor_level_connection_affinity_factor_decay_main=zero_7_exp_decay,
    seed=8675309,
    max_consecutive_lateral_connections=max_consecutive_lateral_connections,
    gate_after_n_lateral_connections=3,
    gate_activation_function=simple_sigmoid,
    p_lateral_connection=p_lateral_connection,
    p_lateral_connection_decay=zero_95_exp_decay,
    num_lateral_connection_tries_per_unit=num_lateral_connection_tries_per_unit,
    learning_rate=learning_rate,
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=[tf.keras.metrics.BinaryAccuracy(),
             tf.keras.metrics.Precision(),
             tf.keras.metrics.Recall()],
    epochs=epochs,
    project_name=f"{PROJECT_NAME}_meta_{meta_trial_number}",
    model_graphs='model_graphs',
    batch_size=batch_size,
    meta_trial_number=meta_trial_number,
    base_models=[base_model],
    train_data_dtype=tf.string)

# %%
# %%time
result = cerebros_automl.run_random_search()
# Out:
# SimpleCerebrosRandomSearch.input_shapes: [()]
# nan
# >nnf>ceil
# k is: 0 value is: [{'1': <class 'cerebros.units.units.InputUnit'>}]
# 0
# k is: 1 value is: [{'6': <class 'cerebros.units.units.DenseUnit'>}, {'5': <class 'cerebros.units.units.DenseUnit'>}, {'5': <class 'cerebros.units.units.DenseUnit'>}, {'6': <class 'cerebros.units.units.DenseUnit'>}, {'3': <class 'cerebros.units.units.DenseUnit'>}, {'6': <class 'cerebros.units.units.DenseUnit'>}]
# 1
# Trying to create level 1
# We think level 1's predecessors are: [0]
# k is: 2 value is: [{'1': <class 'cerebros.units.units.FinalDenseUnit'>}]
# 2
# Trying to create Final level 2
# Trying to create level 2
# We think level final level 2's predecessors are: [0, 1]
# levels:
# [0, 1, 2]
# {'0': 'InputUnitModule'}
# InputLevel.input_shapes [()]
# {'6': <class 'cerebros.units.units.DenseUnit'>}
# {'5': <class 'cerebros.units.units.DenseUnit'>}
# {'5': <class 'cerebros.units.units.DenseUnit'>}
# {'6': <class 'cerebros.units.units.DenseUnit'>}
# {'3': <class 'cerebros.units.units.DenseUnit'>}
# {'6': <class 'cerebros.units.units.DenseUnit'>}
# Debug: I am 2 selecting 1
# debug: meta_level_number
# debug: meta_level_number
# debug: meta_level_number
# debug: meta_level_number
# debug: meta_level_number
# debug: meta_level_number
# debug: meta_level_number
# Setting levels_unmaterialized[0] level_number 0 to have first successor: levels_unmaterialized[:1], having level_numbers of [1, 2]
# Setting levels_unmaterialized[1] level_number 1 to have first successor: levels_unmaterialized[:2], having level_numbers of [2]
# Debug: successor_connectivity_errors_2d []
# $$$$$$>>>>> Base model: <keras.src.engine.functional.Functional object at 0x7cacd0108580>
# InputUnit.input_shape: ()
# {'6': <class 'cerebros.units.units.DenseUnit'>}
# {'5': <class 'cerebros.units.units.DenseUnit'>}
# {'5': <class 'cerebros.units.units.DenseUnit'>}
# {'6': <class 'cerebros.units.units.DenseUnit'>}
# {'3': <class 'cerebros.units.units.DenseUnit'>}
# {'6': <class 'cerebros.units.units.DenseUnit'>}
# debug: meta_level_number
# debug: meta_level_number
# debug: meta_level_number
# debug: meta_level_number
# debug: meta_level_number
# debug: meta_level_number
# Debug: successor_connectivity_errors_2d []
# Debug: successor_connectivity_errors_2d []
# Debug: successor_connectivity_errors_2d []
# Debug: successor_connectivity_errors_2d []
# Debug: successor_connectivity_errors_2d []
# Debug: successor_connectivity_errors_2d []
# materialize:_NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0 called
# materialized network layers
# [<KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>]
# materialized_predecessor_units [<KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>]
# materialize:_NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_1 called
# materialized network layers
# [<KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>]
# materialized_predecessor_units [<KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>]
# materialize:_NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_2 called
# materialized network layers
# [<KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_1_dns_')>, <KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_1_dns_')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>]
# materialized_predecessor_units [<KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_1_dns_')>, <KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_1_dns_')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>]
# materialize:_NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_3 called
# materialized network layers
# [<KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_2_dns_')>, <KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_1_dns_')>, <KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_1_dns_')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>]
# materialized_predecessor_units [<KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_2_dns_')>, <KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_1_dns_')>, <KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_1_dns_')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>]
# materialize:_NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_4 called
# materialized network layers
# [<KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_3_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_3_dns_')>, <KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_2_dns_')>, <KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_1_dns_')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>]
# materialized_predecessor_units [<KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_3_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_3_dns_')>, <KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_2_dns_')>, <KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_1_dns_')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>]
# materialize:_NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_5 called
# materialized network layers
# [<KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_4_dns_')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_4_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_3_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_3_dns_')>, <KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_2_dns_')>, <KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_1_dns_')>, <KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_1_dns_')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>]
# materialized_predecessor_units [<KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_4_dns_')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_4_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_3_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_3_dns_')>, <KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_2_dns_')>, <KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_1_dns_')>, <KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_1_dns_')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>]
# {'1': <class 'cerebros.units.units.FinalDenseUnit'>}
# debug: meta_level_number
# Debug: successor_connectivity_errors_2d []
# materialize:_NeuralNetworkFuture_0000000000000nan_tr_0_FinalDenseLevel_0000000000000002_tr_0_FinalDenseUnit_0000000000000002_tr_0_0 called
# materialized network layers
# [<KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_4_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_5_dns_')>, <KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_2_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_3_dns_')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_4_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0_dns_')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_4_dns_')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_4_dns_')>, <KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_2_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_3_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_3_dns_')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_5_dns_')>, <KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_1_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_5_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0_dns_')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_5_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_5_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (cre ...
# materialized_predecessor_units [<KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_4_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_5_dns_')>, <KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_2_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_3_dns_')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_4_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0_dns_')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_4_dns_')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_4_dns_')>, <KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_2_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_3_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_3_dns_')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_5_dns_')>, <KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_1_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_5_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0_dns_')>, <KerasTensor: shape=(None, 768) dtype=float32 (created by layer 'model')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_5_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_5_dns_')>, <KerasTensor: shape=(None, 6) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0_dns_')>, <KerasTensor: sha ...
# inputs
# KerasTensor(type_spec=TensorSpec(shape=(None,), dtype=tf.string, name='NeuralNetworkFuture_0000000000000nan_tr_0_InputLevel_0000000000000000_tr_0_InputUnit_0000000000000000_tr_0_0_inp'), name='NeuralNetworkFuture_0000000000000nan_tr_0_InputLevel_0000000000000000_tr_0_InputUnit_0000000000000000_tr_0_0_inp', description="created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_InputLevel_0000000000000000_tr_0_InputUnit_0000000000000000_tr_0_0_inp'")
#
# outputs
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='NeuralNetworkFuture_0000000000000nan_tr_0_FinalDenseLevel_0000000000000002_tr_0_FinalDenseUnit_0000000000000002_tr_0_0_dns_/Sigmoid:0', description="created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_FinalDenseLevel_0000000000000002_tr_0_FinalDenseUnit_0000000000000002_tr_0_0_dns_'")
# Model: "NeuralNetworkFuture_0000000000000nan_tr_0_nn_materialized"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  NeuralNetworkFuture_000000  [(None,)]                    0         []
#  0000000nan_tr_0_InputLevel
#  _0000000000000000_tr_0_Inp
#  utUnit_0000000000000000_tr
#  _0_0_inp (InputLayer)
#
#  model (Functional)          (None, 768)                  1244398   ['NeuralNetworkFuture_00000000
#                                                           08        00000nan_tr_0_InputLevel_00000
#                                                                     00000000000_tr_0_InputUnit_000
#                                                                     0000000000000_tr_0_0_inp[0][0]
#                                                                     ']
#
#  NeuralNetworkFuture_000000  (None, 3072)                 0         ['model[0][0]',
#  0000000nan_tr_0_DenseLevel                                          'model[0][0]',
#  _0000000000000001_tr_0_Den                                          'model[0][0]',
#  seUnit_0000000000000001_tr                                          'model[0][0]']
#  _0_1_cat_ (Concatenate)
#
#  NeuralNetworkFuture_000000  (None, 3072)                 12288     ['NeuralNetworkFuture_00000000
#  0000000nan_tr_0_DenseLevel                                         00000nan_tr_0_DenseLevel_00000
#  _0000000000000001_tr_0_Den                                         00000000001_tr_0_DenseUnit_000
#  seUnit_0000000000000001_tr                                         0000000000001_tr_0_1_cat_[0][0
#  _0_1_btn_ (BatchNormalizat                                         ]']
#  ion)
#
#  NeuralNetworkFuture_000000  (None, 5)                    15365     ['NeuralNetworkFuture_00000000
#  0000000nan_tr_0_DenseLevel                                         00000nan_tr_0_DenseLevel_00000
#  _0000000000000001_tr_0_Den                                         00000000001_tr_0_DenseUnit_000
#  seUnit_0000000000000001_tr                                         0000000000001_tr_0_1_btn_[0][0
#  _0_1_dns_ (Dense)                                                  ]']
#
#  NeuralNetworkFuture_000000  (None, 3082)                 0         ['NeuralNetworkFuture_00000000
#  0000000nan_tr_0_DenseLevel                                         00000nan_tr_0_DenseLevel_00000
#  _0000000000000001_tr_0_Den                                         00000000001_tr_0_DenseUnit_000
#  seUnit_0000000000000001_tr                                         0000000000001_tr_0_1_dns_[0][0
#  _0_2_cat_ (Concatenate)                                            ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_0_DenseLevel_00000
#                                                                     00000000001_tr_0_DenseUnit_000
#                                                                     0000000000001_tr_0_1_dns_[0][0
#                                                                     ]',
#                                                                      'model[0][0]',
#                                                                      'model[0][0]',
#                                                                      'model[0][0]',
#                                                                      'model[0][0]']
#
#  NeuralNetworkFuture_000000  (None, 3082)                 12328     ['NeuralNetworkFuture_00000000
#  0000000nan_tr_0_DenseLevel                                         00000nan_tr_0_DenseLevel_00000
#  _0000000000000001_tr_0_Den                                         00000000001_tr_0_DenseUnit_000
#  seUnit_0000000000000001_tr                                         0000000000001_tr_0_2_cat_[0][0
#  _0_2_btn_ (BatchNormalizat                                         ]']
#  ion)
#
#  NeuralNetworkFuture_000000  (None, 5)                    15415     ['NeuralNetworkFuture_00000000
#  0000000nan_tr_0_DenseLevel                                         00000nan_tr_0_DenseLevel_00000
#  _0000000000000001_tr_0_Den                                         00000000001_tr_0_DenseUnit_000
#  seUnit_0000000000000001_tr                                         0000000000001_tr_0_2_btn_[0][0
#  _0_2_dns_ (Dense)                                                  ]']
#
#  NeuralNetworkFuture_000000  (None, 3087)                 0         ['NeuralNetworkFuture_00000000
#  0000000nan_tr_0_DenseLevel                                         00000nan_tr_0_DenseLevel_00000
#  _0000000000000001_tr_0_Den                                         00000000001_tr_0_DenseUnit_000
#  seUnit_0000000000000001_tr                                         0000000000001_tr_0_2_dns_[0][0
#  _0_3_cat_ (Concatenate)                                            ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_0_DenseLevel_00000
#                                                                     00000000001_tr_0_DenseUnit_000
#                                                                     0000000000001_tr_0_1_dns_[0][0
#                                                                     ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_0_DenseLevel_00000
#                                                                     00000000001_tr_0_DenseUnit_000
#                                                                     0000000000001_tr_0_1_dns_[0][0
#                                                                     ]',
#                                                                      'model[0][0]',
#                                                                      'model[0][0]',
#                                                                      'model[0][0]',
#                                                                      'model[0][0]']
#
#  NeuralNetworkFuture_000000  (None, 3087)                 12348     ['NeuralNetworkFuture_00000000
#  0000000nan_tr_0_DenseLevel                                         00000nan_tr_0_DenseLevel_00000
#  _0000000000000001_tr_0_Den                                         00000000001_tr_0_DenseUnit_000
#  seUnit_0000000000000001_tr                                         0000000000001_tr_0_3_cat_[0][0
#  _0_3_btn_ (BatchNormalizat                                         ]']
#  ion)
#
#  NeuralNetworkFuture_000000  (None, 6)                    18528     ['NeuralNetworkFuture_00000000
#  0000000nan_tr_0_DenseLevel                                         00000nan_tr_0_DenseLevel_00000
#  _0000000000000001_tr_0_Den                                         00000000001_tr_0_DenseUnit_000
#  seUnit_0000000000000001_tr                                         0000000000001_tr_0_3_btn_[0][0
#  _0_3_dns_ (Dense)                                                  ]']
#
#  NeuralNetworkFuture_000000  (None, 3094)                 0         ['NeuralNetworkFuture_00000000
#  0000000nan_tr_0_DenseLevel                                         00000nan_tr_0_DenseLevel_00000
#  _0000000000000001_tr_0_Den                                         00000000001_tr_0_DenseUnit_000
#  seUnit_0000000000000001_tr                                         0000000000001_tr_0_3_dns_[0][0
#  _0_4_cat_ (Concatenate)                                            ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_0_DenseLevel_00000
#                                                                     00000000001_tr_0_DenseUnit_000
#                                                                     0000000000001_tr_0_3_dns_[0][0
#                                                                     ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_0_DenseLevel_00000
#                                                                     00000000001_tr_0_DenseUnit_000
#                                                                     0000000000001_tr_0_2_dns_[0][0
#                                                                     ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_0_DenseLevel_00000
#                                                                     00000000001_tr_0_DenseUnit_000
#                                                                     0000000000001_tr_0_1_dns_[0][0
#                                                                     ]',
#                                                                      'model[0][0]',
#                                                                      'model[0][0]',
#                                                                      'model[0][0]',
#                                                                      'model[0][0]']
#
#  NeuralNetworkFuture_000000  (None, 3094)                 12376     ['NeuralNetworkFuture_00000000
#  0000000nan_tr_0_DenseLevel                                         00000nan_tr_0_DenseLevel_00000
#  _0000000000000001_tr_0_Den                                         00000000001_tr_0_DenseUnit_000
#  seUnit_0000000000000001_tr                                         0000000000001_tr_0_4_cat_[0][0
#  _0_4_btn_ (BatchNormalizat                                         ]']
#  ion)
#
#  NeuralNetworkFuture_000000  (None, 3)                    9285      ['NeuralNetworkFuture_00000000
#  0000000nan_tr_0_DenseLevel                                         00000nan_tr_0_DenseLevel_00000
#  _0000000000000001_tr_0_Den                                         00000000001_tr_0_DenseUnit_000
#  seUnit_0000000000000001_tr                                         0000000000001_tr_0_4_btn_[0][0
#  _0_4_dns_ (Dense)                                                  ]']
#
#  NeuralNetworkFuture_000000  (None, 3105)                 0         ['NeuralNetworkFuture_00000000
#  0000000nan_tr_0_DenseLevel                                         00000nan_tr_0_DenseLevel_00000
#  _0000000000000001_tr_0_Den                                         00000000001_tr_0_DenseUnit_000
#  seUnit_0000000000000001_tr                                         0000000000001_tr_0_4_dns_[0][0
#  _0_5_cat_ (Concatenate)                                            ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_0_DenseLevel_00000
#                                                                     00000000001_tr_0_DenseUnit_000
#                                                                     0000000000001_tr_0_4_dns_[0][0
#                                                                     ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_0_DenseLevel_00000
#                                                                     00000000001_tr_0_DenseUnit_000
#                                                                     0000000000001_tr_0_3_dns_[0][0
#                                                                     ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_0_DenseLevel_00000
#                                                                     00000000001_tr_0_DenseUnit_000
#                                                                     0000000000001_tr_0_3_dns_[0][0
#                                                                     ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_0_DenseLevel_00000
#                                                                     00000000001_tr_0_DenseUnit_000
#                                                                     0000000000001_tr_0_2_dns_[0][0
#                                                                     ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_0_DenseLevel_00000
#                                                                     00000000001_tr_0_DenseUnit_000
#                                                                     0000000000001_tr_0_1_dns_[0][0
#                                                                     ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_0_DenseLevel_00000
#                                                                     00000000001_tr_0_DenseUnit_000
#                                                                     0000000000001_tr_0_1_dns_[0][0
#                                                                     ]',
#                                                                      'model[0][0]',
#                                                                      'model[0][0]',
#                                                                      'model[0][0]',
#                                                                      'model[0][0]']
#
#  NeuralNetworkFuture_000000  (None, 3072)                 0         ['model[0][0]',
#  0000000nan_tr_0_DenseLevel                                          'model[0][0]',
#  _0000000000000001_tr_0_Den                                          'model[0][0]',
#  seUnit_0000000000000001_tr                                          'model[0][0]']
#  _0_0_cat_ (Concatenate)
#
#  NeuralNetworkFuture_000000  (None, 3105)                 12420     ['NeuralNetworkFuture_00000000
#  0000000nan_tr_0_DenseLevel                                         00000nan_tr_0_DenseLevel_00000
#  _0000000000000001_tr_0_Den                                         00000000001_tr_0_DenseUnit_000
#  seUnit_0000000000000001_tr                                         0000000000001_tr_0_5_cat_[0][0
#  _0_5_btn_ (BatchNormalizat                                         ]']
#  ion)
#
#  NeuralNetworkFuture_000000  (None, 3072)                 12288     ['NeuralNetworkFuture_00000000
#  0000000nan_tr_0_DenseLevel                                         00000nan_tr_0_DenseLevel_00000
#  _0000000000000001_tr_0_Den                                         00000000001_tr_0_DenseUnit_000
#  seUnit_0000000000000001_tr                                         0000000000001_tr_0_0_cat_[0][0
#  _0_0_btn_ (BatchNormalizat                                         ]']
#  ion)
#
#  NeuralNetworkFuture_000000  (None, 6)                    18636     ['NeuralNetworkFuture_00000000
#  0000000nan_tr_0_DenseLevel                                         00000nan_tr_0_DenseLevel_00000
#  _0000000000000001_tr_0_Den                                         00000000001_tr_0_DenseUnit_000
#  seUnit_0000000000000001_tr                                         0000000000001_tr_0_5_btn_[0][0
#  _0_5_dns_ (Dense)                                                  ]']
#
#  NeuralNetworkFuture_000000  (None, 6)                    18438     ['NeuralNetworkFuture_00000000
#  0000000nan_tr_0_DenseLevel                                         00000nan_tr_0_DenseLevel_00000
#  _0000000000000001_tr_0_Den                                         00000000001_tr_0_DenseUnit_000
#  seUnit_0000000000000001_tr                                         0000000000001_tr_0_0_btn_[0][0
#  _0_0_dns_ (Dense)                                                  ]']
#
#  NeuralNetworkFuture_000000  (None, 1653)                 0         ['NeuralNetworkFuture_00000000
#  0000000nan_tr_0_FinalDense                                         00000nan_tr_0_DenseLevel_00000
#  Level_0000000000000002_tr_                                         00000000001_tr_0_DenseUnit_000
#  0_FinalDenseUnit_000000000                                         0000000000001_tr_0_4_dns_[0][0
#  0000002_tr_0_0_cat_ (Conca                                         ]',
#  tenate)                                                             'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_0_DenseLevel_00000
#                                                                     00000000001_tr_0_DenseUnit_000
#                                                                     0000000000001_tr_0_5_dns_[0][0
#                                                                     ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_0_DenseLevel_00000
#                                                                     00000000001_tr_0_DenseUnit_000
#                                                                     0000000000001_tr_0_2_dns_[0][0
#                                                                     ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_0_DenseLevel_00000
#                                                                     00000000001_tr_0_DenseUnit_000
#                                                                     0000000000001_tr_0_0_dns_[0][0
#                                                                     ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_0_DenseLevel_00000
#                                                                     00000000001_tr_0_DenseUnit_000
#                                                                     0000000000001_tr_0_3_dns_[0][0
#                                                                     ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_0_DenseLevel_00000
#                                                                     00000000001_tr_0_DenseUnit_000
#                                                                     0000000000001_tr_0_4_dns_[0][0
#                                                                     ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_0_DenseLevel_00000
#                                                                     00000000001_tr_0_DenseUnit_000
#                                                                     0000000000001_tr_0_0_dns_[0][0
#                                                                     ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_0_DenseLevel_00000
#                                                                     00000000001_tr_0_DenseUnit_000
#                                                                     0000000000001_tr_0_4_dns_[0][0
#                                                                     ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_0_DenseLevel_00000
#                                                                     00000000001_tr_0_DenseUnit_000
#                                                                     0000000000001_tr_0_4_dns_[0][0
#                                                                     ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_0_DenseLevel_00000
#                                                                     00000000001_tr_0_DenseUnit_000
#                                                                     0000000000001_tr_0_2_dns_[0][0
#                                                                     ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_0_DenseLevel_00000
#                                                                     00000000001_tr_0_DenseUnit_000
#                                                                     0000000000001_tr_0_3_dns_[0][0
#                                                                     ]',
#                                                                      'NeuralNetworkFuture_00000000
# ...
#  seUnit_0000000000000001_tr                                         0000000000001_tr_1_0_cat_[0][0
#  _1_0_btn_ (BatchNormalizat                                         ]']
#  ion)
#
#  NeuralNetworkFuture_000000  (None, 3082)                 12328     ['NeuralNetworkFuture_00000000
#  0000000nan_tr_1_DenseLevel                                         00000nan_tr_1_DenseLevel_00000
#  _0000000000000001_tr_1_Den                                         00000000001_tr_1_DenseUnit_000
#  seUnit_0000000000000001_tr                                         0000000000001_tr_1_3_cat_[0][0
#  _1_3_btn_ (BatchNormalizat                                         ]']
#  ion)
#
#  NeuralNetworkFuture_000000  (None, 1)                    3073      ['NeuralNetworkFuture_00000000
#  0000000nan_tr_1_DenseLevel                                         00000nan_tr_1_DenseLevel_00000
#  _0000000000000001_tr_1_Den                                         00000000001_tr_1_DenseUnit_000
#  seUnit_0000000000000001_tr                                         0000000000001_tr_1_0_btn_[0][0
#  _1_0_dns_ (Dense)                                                  ]']
#
#  NeuralNetworkFuture_000000  (None, 2)                    6166      ['NeuralNetworkFuture_00000000
#  0000000nan_tr_1_DenseLevel                                         00000nan_tr_1_DenseLevel_00000
#  _0000000000000001_tr_1_Den                                         00000000001_tr_1_DenseUnit_000
#  seUnit_0000000000000001_tr                                         0000000000001_tr_1_3_btn_[0][0
#  _1_3_dns_ (Dense)                                                  ]']
#
#  NeuralNetworkFuture_000000  (None, 1576)                 0         ['NeuralNetworkFuture_00000000
#  0000000nan_tr_1_FinalDense                                         00000nan_tr_1_DenseLevel_00000
#  Level_0000000000000002_tr_                                         00000000001_tr_1_DenseUnit_000
#  1_FinalDenseUnit_000000000                                         0000000000001_tr_1_0_dns_[0][0
#  0000002_tr_1_0_cat_ (Conca                                         ]',
#  tenate)                                                             'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_1_DenseLevel_00000
#                                                                     00000000001_tr_1_DenseUnit_000
#                                                                     0000000000001_tr_1_2_dns_[0][0
#                                                                     ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_1_DenseLevel_00000
#                                                                     00000000001_tr_1_DenseUnit_000
#                                                                     0000000000001_tr_1_1_dns_[0][0
#                                                                     ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_1_DenseLevel_00000
#                                                                     00000000001_tr_1_DenseUnit_000
#                                                                     0000000000001_tr_1_2_dns_[0][0
#                                                                     ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_1_DenseLevel_00000
#                                                                     00000000001_tr_1_DenseUnit_000
#                                                                     0000000000001_tr_1_2_dns_[0][0
#                                                                     ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_1_DenseLevel_00000
#                                                                     00000000001_tr_1_DenseUnit_000
#                                                                     0000000000001_tr_1_1_dns_[0][0
#                                                                     ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_1_DenseLevel_00000
#                                                                     00000000001_tr_1_DenseUnit_000
#                                                                     0000000000001_tr_1_2_dns_[0][0
#                                                                     ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_1_DenseLevel_00000
#                                                                     00000000001_tr_1_DenseUnit_000
#                                                                     0000000000001_tr_1_0_dns_[0][0
#                                                                     ]',
#                                                                      'model[1][0]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_1_DenseLevel_00000
#                                                                     00000000001_tr_1_DenseUnit_000
#                                                                     0000000000001_tr_1_0_dns_[0][0
#                                                                     ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_1_DenseLevel_00000
#                                                                     00000000001_tr_1_DenseUnit_000
#                                                                     0000000000001_tr_1_1_dns_[0][0
#                                                                     ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_1_DenseLevel_00000
#                                                                     00000000001_tr_1_DenseUnit_000
#                                                                     0000000000001_tr_1_0_dns_[0][0
#                                                                     ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_1_DenseLevel_00000
#                                                                     00000000001_tr_1_DenseUnit_000
#                                                                     0000000000001_tr_1_3_dns_[0][0
#                                                                     ]',
#                                                                      'model[1][0]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_1_DenseLevel_00000
#                                                                     00000000001_tr_1_DenseUnit_000
#                                                                     0000000000001_tr_1_3_dns_[0][0
#                                                                     ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_1_DenseLevel_00000
#                                                                     00000000001_tr_1_DenseUnit_000
#                                                                     0000000000001_tr_1_1_dns_[0][0
#                                                                     ]',
#                                                                      'NeuralNetworkFuture_00000000
#                                                                     00000nan_tr_1_DenseLevel_00000
#                                                                     00000000001_tr_1_DenseUnit_000
#                                                                     0000000000001_tr_1_1_dns_[0][0
#                                                                     ]']
#
#  NeuralNetworkFuture_000000  (None, 1576)                 6304      ['NeuralNetworkFuture_00000000
#  0000000nan_tr_1_FinalDense                                         00000nan_tr_1_FinalDenseLevel_
#  Level_0000000000000002_tr_                                         0000000000000002_tr_1_FinalDen
#  1_FinalDenseUnit_000000000                                         seUnit_0000000000000002_tr_1_0
#  0000002_tr_1_0_btn_ (Batch                                         _cat_[0][0]']
#  Normalization)
#
#  NeuralNetworkFuture_000000  (None, 1)                    1577      ['NeuralNetworkFuture_00000000
#  0000000nan_tr_1_FinalDense                                         00000nan_tr_1_FinalDenseLevel_
#  Level_0000000000000002_tr_                                         0000000000000002_tr_1_FinalDen
#  1_FinalDenseUnit_000000000                                         seUnit_0000000000000002_tr_1_0
#  0000002_tr_1_0_dns_ (Dense                                         _btn_[0][0]']
#  )
#
# ==================================================================================================
# Total params: 124527687 (475.04 MB)
# Trainable params: 7147987 (27.27 MB)
# Non-trainable params: 117379700 (447.77 MB)
# __________________________________________________________________________________________________
# None
# Epoch 1/6
# 133/133 [==============================] - 89s 503ms/step - loss: 0.0848 - binary_accuracy: 0.9638 - precision: 0.9618 - recall: 0.9461 - val_loss: 0.1134 - val_binary_accuracy: 0.9615 - val_precision: 0.9364 - val_recall: 0.9693
# Epoch 2/6
# 133/133 [==============================] - 60s 447ms/step - loss: 0.0672 - binary_accuracy: 0.9731 - precision: 0.9653 - recall: 0.9664 - val_loss: 0.1028 - val_binary_accuracy: 0.9597 - val_precision: 0.9409 - val_recall: 0.9594
# Epoch 3/6
# 133/133 [==============================] - 60s 454ms/step - loss: 0.0506 - binary_accuracy: 0.9825 - precision: 0.9761 - recall: 0.9796 - val_loss: 0.1055 - val_binary_accuracy: 0.9636 - val_precision: 0.9368 - val_recall: 0.9748
# Epoch 4/6
# 133/133 [==============================] - 60s 455ms/step - loss: 0.0441 - binary_accuracy: 0.9816 - precision: 0.9761 - recall: 0.9772 - val_loss: 0.2665 - val_binary_accuracy: 0.9391 - val_precision: 0.8713 - val_recall: 0.9945
# Epoch 5/6
# 133/133 [==============================] - 61s 457ms/step - loss: 0.0498 - binary_accuracy: 0.9835 - precision: 0.9779 - recall: 0.9802 - val_loss: 0.1107 - val_binary_accuracy: 0.9549 - val_precision: 0.9776 - val_recall: 0.9079
# Epoch 6/6
# 133/133 [==============================] - 61s 460ms/step - loss: 0.0380 - binary_accuracy: 0.9837 - precision: 0.9802 - recall: 0.9784 - val_loss: 0.1859 - val_binary_accuracy: 0.9378 - val_precision: 0.9861 - val_recall: 0.8564
# this is neural_network_spec_file 2023_11_04_17_49_cerebros_auto_ml_phishing_email_test_meta_42/model_architectures/tr_0000000000000001_subtrial_0000000000000000.txt
# /usr/local/lib/python3.10/dist-packages/keras/src/activations.py:549: UserWarning: The object being serialized includes a `lambda`. This is unsafe. In order to reload the object, you will have to pass `safe_mode=False` to the loading function. Please avoid using `lambda` in the future, and use named Python functions instead. This is the `lambda` being serialized:                 activation=lambda x: keras.activations.gelu(
#                     x, approximate=True
#                 ),
#
#   fn_config = serialization_lib.serialize_keras_object(activation)
# returning trial 1 oracles
#        loss  binary_accuracy  precision    recall  val_loss  \
# 0  0.084823         0.963809   0.961796  0.946145  0.113410
# 1  0.067244         0.973101   0.965290  0.966447  0.102755
# 2  0.050570         0.982539   0.976119  0.979629  0.105537
# 3  0.044113         0.981595   0.976062  0.977232  0.266534
# 4  0.049816         0.983483   0.977884  0.980228  0.110673
# 5  0.037963         0.983719   0.980192  0.978430  0.185889
#
#    val_binary_accuracy  val_precision  val_recall  trial_number  \
# 0             0.961454       0.936441    0.969298             1
# 1             0.959702       0.940860    0.959430             1
# 2             0.963644       0.936776    0.974781             1
# 3             0.939115       0.871278    0.994518             1
# 4             0.954884       0.977568    0.907895             1
# 5             0.937801       0.986111    0.856360             1
#
#    subtrial_number                                         model_name
# 0                0  2023_11_04_17_49_cerebros_auto_ml_phishing_ema...
# 1                0  2023_11_04_17_49_cerebros_auto_ml_phishing_ema...
# 2                0  2023_11_04_17_49_cerebros_auto_ml_phishing_ema...
# 3                0  2023_11_04_17_49_cerebros_auto_ml_phishing_ema...
# 4                0  2023_11_04_17_49_cerebros_auto_ml_phishing_ema...
# 5                0  2023_11_04_17_49_cerebros_auto_ml_phishing_ema...
# Index(['loss', 'binary_accuracy', 'precision', 'recall', 'val_loss',
#        'val_binary_accuracy', 'val_precision', 'val_recall', 'trial_number',
#        'subtrial_number', 'model_name'],
#       dtype='object')
# metric_to_rank_by is: 'val_binary_accuracy'
# Type of metric_to_rank_by is: <class 'str'>
# Best result this trial was: 0.9636443257331848
# Type of best result: <class 'float'>
# Best model name: 2023_11_04_17_49_cerebros_auto_ml_phishing_email_test_meta_42/models/tr_0000000000000001_subtrial_0000000000000000.keras
# CPU times: user 13min 38s, sys: 29.4 s, total: 14min 8s
# Wall time: 14min 27s

# %%
print(f'Best accuracy achieved is {result}')
print(f'binary accuracy')
# Out:
# Best accuracy achieved is 0.9636443257331848
# binary accuracy

# %% [markdown]
# ### Testing the best model found

# %%
#
# Load the best model (taking into account that it has a custom layer)
#
best_model_found =\
tf.keras.models.load_model(cerebros_automl.best_model_path,\
custom_objects={'GPT2Layer': GPT2Layer(max_seq_length)})
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/activations.py:549: UserWarning: The object being serialized includes a `lambda`. This is unsafe. In order to reload the object, you will have to pass `safe_mode=False` to the loading function. Please avoid using `lambda` in the future, and use named Python functions instead. This is the `lambda` being serialized:                 activation=lambda x: keras.activations.gelu(
#                     x, approximate=True
#                 ),
#
#   fn_config = serialization_lib.serialize_keras_object(activation)

# %%
best_model_found.evaluate(X_test, y_test)
# Out:
# 379/379 [==============================] - 212s 540ms/step - loss: 0.2086 - binary_accuracy: 0.9347 - precision: 0.9903 - recall: 0.8410
# [0.20856627821922302,
#  0.9346982836723328,
#  0.9902936816215515,
#  0.8410484194755554]

# %% [markdown]
# ### Training the best model on a larger dataset, and testing again

# %%
# Train / test split : we give 65% of the data for training,
# now that we have found the best model
X_train, X_test, y_train, y_test = \
train_test_split(X, y, test_size=0.35, shuffle=False)

# %%
optimizer = Adam(learning_rate=0.0005)
#loss=tf.keras.losses.BinaryCrossentropy()
loss = tf.keras.losses.CategoricalHinge()
metrics=[tf.keras.metrics.BinaryAccuracy(),
         tf.keras.metrics.Precision(),
         tf.keras.metrics.Recall()]
best_model_found.compile(optimizer=optimizer,
                         loss=loss,
                         metrics=metrics)

# %%
best_model_found.fit(X_train, y_train, validation_split=0.35, epochs=3)
# Out:
# Epoch 1/3
# 246/246 [==============================] - 173s 611ms/step - loss: 0.6304 - binary_accuracy: 0.9752 - precision_1: 0.9600 - recall_1: 0.9782 - val_loss: 0.6497 - val_binary_accuracy: 0.9573 - val_precision_1: 0.9465 - val_recall_1: 0.9447
# Epoch 2/3
# 246/246 [==============================] - 134s 544ms/step - loss: 0.6284 - binary_accuracy: 0.9766 - precision_1: 0.9567 - recall_1: 0.9855 - val_loss: 0.6519 - val_binary_accuracy: 0.9561 - val_precision_1: 0.9501 - val_recall_1: 0.9375
# Epoch 3/3
# 246/246 [==============================] - 135s 551ms/step - loss: 0.6279 - binary_accuracy: 0.9770 - precision_1: 0.9581 - recall_1: 0.9849 - val_loss: 0.6477 - val_binary_accuracy: 0.9601 - val_precision_1: 0.9437 - val_recall_1: 0.9556

# %%
best_model_found.evaluate(X_test, y_test)
# Out:
# 204/204 [==============================] - 73s 360ms/step - loss: 0.6464 - binary_accuracy: 0.9658 - precision_1: 0.9631 - recall_1: 0.9483
# [0.6463907361030579,
#  0.9658080339431763,
#  0.9631262421607971,
#  0.9483031034469604]
