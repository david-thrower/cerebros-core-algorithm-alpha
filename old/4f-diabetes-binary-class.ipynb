# %%
! pip3 install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting jax==0.4.1
#   Downloading jax-0.4.1.tar.gz (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 49.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting jaxlib==0.4.1
#   Downloading jaxlib-0.4.1-cp38-cp38-manylinux2014_x86_64.whl (71.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.3/71.3 MB 31.3 MB/s eta 0:00:0000:0100:01
# Collecting pendulum==2.1.2
#   Downloading pendulum-2.1.2-cp38-cp38-manylinux1_x86_64.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.7/155.7 KB 35.0 MB/s eta 0:00:00
# Collecting tensorflow==2.11.0
#   Downloading tensorflow-2.11.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (588.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 588.3/588.3 MB 4.1 MB/s eta 0:00:0000:0100:01
# Collecting numpy==1.24.0
#   Downloading numpy-1.24.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 75.8 MB/s eta 0:00:0000:0100:01
# Collecting pandas==1.5.2
#   Downloading pandas-1.5.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 114.2 MB/s eta 0:00:0000:0100:01
# Collecting pyvis==0.3.1
#   Downloading pyvis-0.3.1.tar.gz (748 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 748.9/748.9 KB 80.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting plotly==5.11.0
#   Downloading plotly-5.11.0-py2.py3-none-any.whl (15.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 106.6 MB/s eta 0:00:0000:0100:01
# Collecting matplotlib==3.6.2
#   Downloading matplotlib-3.6.2-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 95.7 MB/s eta 0:00:00:00:0100:01
# Collecting opt_einsum
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 KB 14.9 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.8/dist-packages (from jax==0.4.1->-r requirements.txt (line 1)) (1.6.3)
# Collecting pytzdata>=2020.1
#   Downloading pytzdata-2020.1-py2.py3-none-any.whl (489 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 490.0/490.0 KB 61.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0,>=2.6 in /usr/local/lib/python3.8/dist-packages (from pendulum==2.1.2->-r requirements.txt (line 3)) (2.8.2)
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting absl-py>=1.0.0
#   Downloading absl_py-1.3.0-py3-none-any.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.6/124.6 KB 30.4 MB/s eta 0:00:00
# Collecting libclang>=13.0.0
#   Downloading libclang-14.0.6-py2.py3-none-manylinux2010_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 120.9 MB/s eta 0:00:0000:0100:01
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 KB 13.3 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.12,>=2.11.0
#   Downloading tensorflow_estimator-2.11.0-py2.py3-none-any.whl (439 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.2/439.2 KB 61.0 MB/s eta 0:00:00
# Collecting h5py>=2.9.0
#   Downloading h5py-3.7.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 124.3 MB/s eta 0:00:0000:01
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.11.0->-r requirements.txt (line 4)) (1.14.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.11.0->-r requirements.txt (line 4)) (3.10.0.2)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.29.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 109.6 MB/s eta 0:00:00
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.11.0->-r requirements.txt (line 4)) (1.50.0)
# Collecting keras<2.12,>=2.11.0
#   Downloading keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 110.4 MB/s eta 0:00:00
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.11.0->-r requirements.txt (line 4)) (2.0.1)
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 95.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.11.0->-r requirements.txt (line 4)) (21.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.11.0->-r requirements.txt (line 4)) (1.16.0)
# Collecting tensorboard<2.12,>=2.11
#   Downloading tensorboard-2.11.0-py3-none-any.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 131.2 MB/s eta 0:00:0000:01
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.11.0->-r requirements.txt (line 4)) (62.0.0)
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-23.1.4-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas==1.5.2->-r requirements.txt (line 6)) (2022.5)
# Requirement already satisfied: jinja2>=2.9.6 in /usr/local/lib/python3.8/dist-packages (from pyvis==0.3.1->-r requirements.txt (line 7)) (3.0.3)
# Requirement already satisfied: networkx>=1.11 in /usr/local/lib/python3.8/dist-packages (from pyvis==0.3.1->-r requirements.txt (line 7)) (2.6.3)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from pyvis==0.3.1->-r requirements.txt (line 7)) (8.5.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from pyvis==0.3.1->-r requirements.txt (line 7)) (2.2.0)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.1.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib==3.6.2->-r requirements.txt (line 9)) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib==3.6.2->-r requirements.txt (line 9)) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib==3.6.2->-r requirements.txt (line 9)) (0.11.0)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 KB 91.7 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.0/296.0 KB 52.0 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib==3.6.2->-r requirements.txt (line 9)) (3.0.9)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow==2.11.0->-r requirements.txt (line 4)) (0.30.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython>=5.3.0->pyvis==0.3.1->-r requirements.txt (line 7)) (0.7.5)
# Requirement already satisfied: stack-data in /usr/local/lib/python3.8/dist-packages (from ipython>=5.3.0->pyvis==0.3.1->-r requirements.txt (line 7)) (0.5.1)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.8/dist-packages (from ipython>=5.3.0->pyvis==0.3.1->-r requirements.txt (line 7)) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.8/dist-packages (from ipython>=5.3.0->pyvis==0.3.1->-r requirements.txt (line 7)) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython>=5.3.0->pyvis==0.3.1->-r requirements.txt (line 7)) (5.1.1)
# Requirement already satisfied: traitlets>=5 in /usr/local/lib/python3.8/dist-packages (from ipython>=5.3.0->pyvis==0.3.1->-r requirements.txt (line 7)) (5.5.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.8/dist-packages (from ipython>=5.3.0->pyvis==0.3.1->-r requirements.txt (line 7)) (0.18.1)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.8/dist-packages (from ipython>=5.3.0->pyvis==0.3.1->-r requirements.txt (line 7)) (2.13.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython>=5.3.0->pyvis==0.3.1->-r requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /usr/local/lib/python3.8/dist-packages (from ipython>=5.3.0->pyvis==0.3.1->-r requirements.txt (line 7)) (3.0.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from jinja2>=2.9.6->pyvis==0.3.1->-r requirements.txt (line 7)) (2.1.1)
# Collecting scipy>=1.5
#   Downloading scipy-1.10.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 58.8 MB/s eta 0:00:0000:0100:01
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.1-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.3/93.3 KB 21.7 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 KB 77.4 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 121.2 MB/s eta 0:00:0000:01
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow==2.11.0->-r requirements.txt (line 4)) (1.34.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow==2.11.0->-r requirements.txt (line 4)) (2.28.1)
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.2.2-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.7/232.7 KB 43.9 MB/s eta 0:00:00
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow==2.11.0->-r requirements.txt (line 4)) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow==2.11.0->-r requirements.txt (line 4)) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow==2.11.0->-r requirements.txt (line 4)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow==2.11.0->-r requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.16->ipython>=5.3.0->pyvis==0.3.1->-r requirements.txt (line 7)) (0.8.3)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow==2.11.0->-r requirements.txt (line 4)) (5.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect>4.3->ipython>=5.3.0->pyvis==0.3.1->-r requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=5.3.0->pyvis==0.3.1->-r requirements.txt (line 7)) (0.2.5)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow==2.11.0->-r requirements.txt (line 4)) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow==2.11.0->-r requirements.txt (line 4)) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow==2.11.0->-r requirements.txt (line 4)) (2021.5.30)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow==2.11.0->-r requirements.txt (line 4)) (2.1.1)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.8/dist-packages (from stack-data->ipython>=5.3.0->pyvis==0.3.1->-r requirements.txt (line 7)) (0.2.2)
# Requirement already satisfied: asttokens in /usr/local/lib/python3.8/dist-packages (from stack-data->ipython>=5.3.0->pyvis==0.3.1->-r requirements.txt (line 7)) (2.0.8)
# Requirement already satisfied: executing in /usr/local/lib/python3.8/dist-packages (from stack-data->ipython>=5.3.0->pyvis==0.3.1->-r requirements.txt (line 7)) (1.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow==2.11.0->-r requirements.txt (line 4)) (3.10.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow==2.11.0->-r requirements.txt (line 4)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow==2.11.0->-r requirements.txt (line 4)) (3.2.2)
# Building wheels for collected packages: jax, pyvis
#   Building wheel for jax (setup.py) ... done
#   Created wheel for jax: filename=jax-0.4.1-py3-none-any.whl size=1338540 sha256=4dd3cdffd42fef2465a36f88c3a1f8f0c583bb5d18e9acac162e3b406958278f
#   Stored in directory: /home/jovyan/.cache/pip/wheels/e2/c2/cc/ac766a5c8ed28aec746fc292690d3e2e3790b554d2a6abacb7
#   Building wheel for pyvis (setup.py) ... done
#   Created wheel for pyvis: filename=pyvis-0.3.1-py3-none-any.whl size=756330 sha256=1ff7c49e2edcdf87a7f258fe45b468ac830360ed57ebd9e906f804a0df3e03a5
#   Stored in directory: /home/jovyan/.cache/pip/wheels/a4/0c/61/8469ca276f96ab772c3acc7f47d71e9737cbdf6f446f017f48
# Successfully built jax pyvis
# Installing collected packages: tensorboard-plugin-wit, libclang, flatbuffers, werkzeug, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, tenacity, pytzdata, protobuf, numpy, keras, google-pasta, gast, fonttools, astunparse, absl-py, scipy, plotly, pendulum, pandas, opt_einsum, markdown, h5py, contourpy, matplotlib, jaxlib, jax, google-auth-oauthlib, tensorboard, pyvis, tensorflow
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.3 requires numpy<1.20,>=1.16.0, but you have numpy 1.24.0 which is incompatible.
# ml-metadata 0.30.0 requires absl-py<0.13,>=0.9, but you have absl-py 1.3.0 which is incompatible.
# kubeflow-kale 2.0rc3.post0+6.g3f6dfd87b requires matplotlib<3.4.0, but you have matplotlib 3.6.2 which is incompatible.
# kubeflow-kale 2.0rc3.post0+6.g3f6dfd87b requires scipy<1.7, but you have scipy 1.10.0 which is incompatible.
# kserve 0.8.0 requires numpy~=1.19.2, but you have numpy 1.24.0 which is incompatible.
# kfp 1.7.post0+41.gb3589b6c6 requires absl-py<=0.11,>=0.9, but you have absl-py 1.3.0 which is incompatible.
# Successfully installed absl-py-1.3.0 astunparse-1.6.3 contourpy-1.0.6 flatbuffers-23.1.4 fonttools-4.38.0 gast-0.4.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 h5py-3.7.0 jax-0.4.1 jaxlib-0.4.1 keras-2.11.0 libclang-14.0.6 markdown-3.4.1 matplotlib-3.6.2 numpy-1.24.0 opt_einsum-3.3.0 pandas-1.5.2 pendulum-2.1.2 plotly-5.11.0 protobuf-3.19.6 pytzdata-2020.1 pyvis-0.3.1 scipy-1.10.0 tenacity-8.1.0 tensorboard-2.11.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.11.0 tensorflow-estimator-2.11.0 tensorflow-io-gcs-filesystem-0.29.0 werkzeug-2.2.2
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import sys
import IPython
app = IPython.Application.instance()
app.kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}

# %%
import numpy as np
# from multiprocessing import Pool  # , Process
from cerebros.simplecerebrosrandomsearch.simple_cerebros_random_search\
    import SimpleCerebrosRandomSearch
import pendulum
import pandas as pd
import tensorflow as tf
from cerebros.units.units import DenseUnit
from cerebros.denseautomlstructuralcomponent.dense_automl_structural_component\
    import zero_7_exp_decay, zero_95_exp_decay, simple_sigmoid
from ast import literal_eval
# Out:
# 2023-01-09 06:03:14.664523: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-01-09 06:03:15.564873: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-01-09 06:03:15.565008: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-01-09 06:03:15.565021: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-01-09 06:03:16.547872: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-01-09 06:03:16.547908: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)

# %%
activation = 'relu'
predecessor_level_connection_affinity_factor_first = 2.0
predecessor_level_connection_affinity_factor_main = 0.97
max_consecutive_lateral_connections = 5
p_lateral_connection = 0.97
num_lateral_connection_tries_per_unit = 2
learning_rate = 0.001
epochs = 10 # [1, 100]
batch_size = 100
maximum_levels = 6 # [3,7]
maximum_units_per_level = 4 # [2,10]
maximum_neurons_per_unit = 4 # [2,20]

# %%
raw_data = pd.read_csv('diabetes.csv')
label = raw_data.pop('Outcome').astype(int).values

data_numeric = raw_data.astype(float)


data_np = data_numeric.values

# np.save('label', label, allow_pickle=True)
# np.save('data', data_np, allow_pickle=True)

TIME = pendulum.now(tz='America/New_York').__str__()[:16]\
    .replace('T', '_')\
    .replace(':', '_')\
    .replace('-', '_')
PROJECT_NAME = f'{TIME}_cerebros_auto_ml_test'

# data_np = np.load('data.npy', allow_pickle=True)
# labels = np.load('labels.npy', allow_pickle=True)

tensor_x =\
    tf.constant(data_np)

training_x = [tensor_x]

INPUT_SHAPES = [training_x[i].shape[1] for i in np.arange(len(training_x))]


#alcohol_labels = tf.constant(pd.get_dummies(pd.cut(white['alcohol'], np.arange(
#    white['alcohol'].min(), white['alcohol'].max()))).values)
# quality_labels = tf.constant(pd.get_dummies(white['quality']).values)

train_labels = [label]

# OUTPUT_SHAPES = [1]  # [train_labels[i].shape[1]
# for i in np.arange(len(train_labels))]

# %%
INPUT_SHAPES = [training_x[i].shape[1] for i in np.arange(len(training_x))]

OUTPUT_SHAPES = [1]

meta_trial_number = str(int(np.random.random() * 10 ** 12))


cerebros_automl = SimpleCerebrosRandomSearch(
    unit_type=DenseUnit,
    input_shapes=INPUT_SHAPES,
    output_shapes=OUTPUT_SHAPES,
    training_data=training_x,
    labels=train_labels,
    validation_split=0.35,
    direction='maximize',
    metric_to_rank_by="val_binary_accuracy",
    minimum_levels=2,
    maximum_levels=maximum_levels,
    minimum_units_per_level=1,
    maximum_units_per_level=maximum_units_per_level,
    minimum_neurons_per_unit=1,
    maximum_neurons_per_unit=maximum_neurons_per_unit,
    activation=activation,
    final_activation='sigmoid',
    number_of_architecture_moities_to_try=7,
    number_of_tries_per_architecture_moity=1,
    minimum_skip_connection_depth=1,
    maximum_skip_connection_depth=7,
    predecessor_level_connection_affinity_factor_first=predecessor_level_connection_affinity_factor_first,
    predecessor_level_connection_affinity_factor_first_rounding_rule='ceil',
    predecessor_level_connection_affinity_factor_main=predecessor_level_connection_affinity_factor_main,
    predecessor_level_connection_affinity_factor_main_rounding_rule='ceil',
    predecessor_level_connection_affinity_factor_decay_main=zero_7_exp_decay,
    seed=8675309,
    max_consecutive_lateral_connections=max_consecutive_lateral_connections,
    gate_after_n_lateral_connections=3,
    gate_activation_function=simple_sigmoid,
    p_lateral_connection=p_lateral_connection,
    p_lateral_connection_decay=zero_95_exp_decay,
    num_lateral_connection_tries_per_unit=num_lateral_connection_tries_per_unit,
    learning_rate=learning_rate,
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=[tf.keras.metrics.BinaryAccuracy(),
             tf.keras.metrics.Precision(),
             tf.keras.metrics.Recall()],
    epochs=epochs,
    project_name=f"{PROJECT_NAME}_meta_{meta_trial_number}",
    # use_multiprocessing_for_multiple_neural_networks=False,  # pull this param
    model_graphs='model_graphs',
    batch_size=batch_size,
    meta_trial_number=meta_trial_number)
val_binary_accuracy = cerebros_automl.run_random_search()
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# nan
# >nnf>ceil
# k is: 0 value is: [{'1': <class 'cerebros.units.units.InputUnit'>}]
# 0
# k is: 1 value is: [{'3': <class 'cerebros.units.units.DenseUnit'>}]
# 1
# Trying to create level 1
# We think level 1's predecessors are: [0]
# k is: 2 value is: [{'4': <class 'cerebros.units.units.DenseUnit'>}, {'2': <class 'cerebros.units.units.DenseUnit'>}, {'2': <class 'cerebros.units.units.DenseUnit'>}, {'1': <class 'cerebros.units.units.DenseUnit'>}]
# 2
# Trying to create level 2
# We think level 2's predecessors are: [0, 1]
# k is: 3 value is: [{'2': <class 'cerebros.units.units.DenseUnit'>}, {'3': <class 'cerebros.units.units.DenseUnit'>}, {'4': <class 'cerebros.units.units.DenseUnit'>}]
# 3
# Trying to create level 3
# We think level 3's predecessors are: [0, 1, 2]
# k is: 4 value is: [{'1': <class 'cerebros.units.units.FinalDenseUnit'>}]
# 4
# Trying to create Final level 4
# Trying to create level 4
# We think level final level 4's predecessors are: [0, 1, 2, 3]
# levels:
# [0, 1, 2, 3, 4]
# {'0': 'InputUnitModule'}
# {'3': <class 'cerebros.units.units.DenseUnit'>}
# {'4': <class 'cerebros.units.units.DenseUnit'>}
# {'2': <class 'cerebros.units.units.DenseUnit'>}
# {'2': <class 'cerebros.units.units.DenseUnit'>}
# {'1': <class 'cerebros.units.units.DenseUnit'>}
# {'2': <class 'cerebros.units.units.DenseUnit'>}
# {'3': <class 'cerebros.units.units.DenseUnit'>}
# {'4': <class 'cerebros.units.units.DenseUnit'>}
# Debug: I am 4 selecting 3
# debug: meta_level_number
# debug: meta_level_number
# debug: meta_level_number
# debug: meta_level_number
# debug: meta_level_number
# debug: meta_level_number
# debug: meta_level_number
# debug: meta_level_number
# debug: meta_level_number
# Setting levels_unmaterialized[0] level_number 0 to have first successor: levels_unmaterialized[:1], having level_numbers of [1, 2, 3, 4]
# Setting levels_unmaterialized[1] level_number 1 to have first successor: levels_unmaterialized[:2], having level_numbers of [2, 3, 4]
# Setting levels_unmaterialized[2] level_number 2 to have first successor: levels_unmaterialized[:3], having level_numbers of [3, 4]
# Setting levels_unmaterialized[3] level_number 3 to have first successor: levels_unmaterialized[:4], having level_numbers of [4]
# Debug: successor_connectivity_errors_2d []
# {'3': <class 'cerebros.units.units.DenseUnit'>}
# debug: meta_level_number
# Debug: successor_connectivity_errors_2d []
# materialize:_NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0 called
# materialized network layers
# [<KerasTensor: shape=(None, 8) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_InputLevel_0000000000000000_tr_0_InputUnit_0000000000000000_tr_0_0_inp')>, <KerasTensor: shape=(None, 8) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_InputLevel_0000000000000000_tr_0_InputUnit_0000000000000000_tr_0_0_inp')>, <KerasTensor: shape=(None, 8) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_InputLevel_0000000000000000_tr_0_InputUnit_0000000000000000_tr_0_0_inp')>, <KerasTensor: shape=(None, 8) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_InputLevel_0000000000000000_tr_0_InputUnit_0000000000000000_tr_0_0_inp')>]
# {'4': <class 'cerebros.units.units.DenseUnit'>}
# {'2': <class 'cerebros.units.units.DenseUnit'>}
# {'2': <class 'cerebros.units.units.DenseUnit'>}
# {'1': <class 'cerebros.units.units.DenseUnit'>}
# debug: meta_level_number
# debug: meta_level_number
# debug: meta_level_number
# debug: meta_level_number
# Debug: successor_connectivity_errors_2d []
# Debug: successor_connectivity_errors_2d []
# Debug: successor_connectivity_errors_2d []
# Debug: successor_connectivity_errors_2d []
# materialize:_NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_0 called
# materialized network layers
# [<KerasTensor: shape=(None, 8) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_InputLevel_0000000000000000_tr_0_InputUnit_0000000000000000_tr_0_0_inp')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0_dns_')>, <KerasTensor: shape=(None, 8) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_InputLevel_0000000000000000_tr_0_InputUnit_0000000000000000_tr_0_0_inp')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0_dns_')>]
# materialize:_NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_1 called
# materialized network layers
# [<KerasTensor: shape=(None, 8) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_InputLevel_0000000000000000_tr_0_InputUnit_0000000000000000_tr_0_0_inp')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0_dns_')>, <KerasTensor: shape=(None, 8) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_InputLevel_0000000000000000_tr_0_InputUnit_0000000000000000_tr_0_0_inp')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0_dns_')>]
# materialize:_NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_2 called
# materialized network layers
# [<KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_1_dns_')>, <KerasTensor: shape=(None, 8) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_InputLevel_0000000000000000_tr_0_InputUnit_0000000000000000_tr_0_0_inp')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0_dns_')>, <KerasTensor: shape=(None, 8) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_InputLevel_0000000000000000_tr_0_InputUnit_0000000000000000_tr_0_0_inp')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0_dns_')>]
# materialize:_NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_3 called
# materialized network layers
# [<KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_2_dns_')>, <KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_1_dns_')>, <KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_1_dns_')>, <KerasTensor: shape=(None, 8) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_InputLevel_0000000000000000_tr_0_InputUnit_0000000000000000_tr_0_0_inp')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0_dns_')>, <KerasTensor: shape=(None, 8) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_InputLevel_0000000000000000_tr_0_InputUnit_0000000000000000_tr_0_0_inp')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0_dns_')>]
# {'2': <class 'cerebros.units.units.DenseUnit'>}
# {'3': <class 'cerebros.units.units.DenseUnit'>}
# {'4': <class 'cerebros.units.units.DenseUnit'>}
# debug: meta_level_number
# debug: meta_level_number
# debug: meta_level_number
# Debug: successor_connectivity_errors_2d []
# Debug: successor_connectivity_errors_2d []
# Debug: successor_connectivity_errors_2d []
# materialize:_NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000003_tr_0_DenseUnit_0000000000000003_tr_0_0 called
# materialized network layers
# [<KerasTensor: shape=(None, 8) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_InputLevel_0000000000000000_tr_0_InputUnit_0000000000000000_tr_0_0_inp')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0_dns_')>, <KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_1_dns_')>, <KerasTensor: shape=(None, 4) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_0_dns_')>, <KerasTensor: shape=(None, 4) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_0_dns_')>, <KerasTensor: shape=(None, 8) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_InputLevel_0000000000000000_tr_0_InputUnit_0000000000000000_tr_0_0_inp')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0_dns_')>, <KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_1_dns_')>, <KerasTensor: shape=(None, 4) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_0_dns_')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_3_dns_')>]
# materialize:_NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000003_tr_0_DenseUnit_0000000000000003_tr_0_1 called
# materialized network layers
# [<KerasTensor: shape=(None, 8) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_InputLevel_0000000000000000_tr_0_InputUnit_0000000000000000_tr_0_0_inp')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0_dns_')>, <KerasTensor: shape=(None, 4) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_0_dns_')>, <KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_2_dns_')>, <KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_2_dns_')>, <KerasTensor: shape=(None, 8) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_InputLevel_0000000000000000_tr_0_InputUnit_0000000000000000_tr_0_0_inp')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0_dns_')>, <KerasTensor: shape=(None, 4) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_0_dns_')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_3_dns_')>, <KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_1_dns_')>]
# materialize:_NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000003_tr_0_DenseUnit_0000000000000003_tr_0_2 called
# materialized network layers
# [<KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000003_tr_0_DenseUnit_0000000000000003_tr_0_1_dns_')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000003_tr_0_DenseUnit_0000000000000003_tr_0_1_dns_')>, <KerasTensor: shape=(None, 8) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_InputLevel_0000000000000000_tr_0_InputUnit_0000000000000000_tr_0_0_inp')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0_dns_')>, <KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_1_dns_')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_3_dns_')>, <KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_1_dns_')>, <KerasTensor: shape=(None, 8) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_InputLevel_0000000000000000_tr_0_InputUnit_0000000000000000_tr_0_0_inp')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0_dns_')>, <KerasTensor: shape=(None, 4) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_0_dns_')>, <KerasTensor: shape=(None, 4) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_0_dns_')>, <KerasTensor: shape=(None, 4) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_0_dns_')>]
# {'1': <class 'cerebros.units.units.FinalDenseUnit'>}
# debug: meta_level_number
# Debug: successor_connectivity_errors_2d []
# materialize:_NeuralNetworkFuture_0000000000000nan_tr_0_FinalDenseLevel_0000000000000004_tr_0_FinalDenseUnit_0000000000000004_tr_0_0 called
# materialized network layers
# [<KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000003_tr_0_DenseUnit_0000000000000003_tr_0_1_dns_')>, <KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000003_tr_0_DenseUnit_0000000000000003_tr_0_0_dns_')>, <KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000003_tr_0_DenseUnit_0000000000000003_tr_0_0_dns_')>, <KerasTensor: shape=(None, 4) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000003_tr_0_DenseUnit_0000000000000003_tr_0_2_dns_')>, <KerasTensor: shape=(None, 4) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000003_tr_0_DenseUnit_0000000000000003_tr_0_2_dns_')>, <KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000003_tr_0_DenseUnit_0000000000000003_tr_0_0_dns_')>, <KerasTensor: shape=(None, 8) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_InputLevel_0000000000000000_tr_0_InputUnit_0000000000000000_tr_0_0_inp')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0_dns_')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_3_dns_')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_3_dns_')>, <KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000003_tr_0_DenseUnit_0000000000000003_tr_0_0_dns_')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000003_tr_0_DenseUnit_0000000000000003_tr_0_1_dns_')>, <KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000003_tr_0_DenseUnit_0000000000000003_tr_0_0_dns_')>, <KerasTensor: shape=(None, 8) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_InputLevel_0000000000000000_tr_0_InputUnit_0000000000000000_tr_0_0_inp')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000001_tr_0_DenseUnit_0000000000000001_tr_0_0_dns_')>, <KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_1_dns_')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000002_tr_0_DenseUnit_0000000000000002_tr_0_3_dns_')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000003_tr_0_DenseUnit_0000000000000003_tr_0_1_dns_')>, <KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000003_tr_0_DenseUnit_0000000000000003_tr_0_0_dns_')>, <KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_DenseLevel_0000000000000003_tr_0_DenseUnit_0000000000000003_tr_0_0_dns_')>]
# inputs
# KerasTensor(type_spec=TensorSpec(shape=(None, 8), dtype=tf.float32, name='NeuralNetworkFuture_0000000000000nan_tr_0_InputLevel_0000000000000000_tr_0_InputUnit_0000000000000000_tr_0_0_inp'), name='NeuralNetworkFuture_0000000000000nan_tr_0_InputLevel_0000000000000000_tr_0_InputUnit_0000000000000000_tr_0_0_inp', description="created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_InputLevel_0000000000000000_tr_0_InputUnit_0000000000000000_tr_0_0_inp'")
#
# outputs
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='NeuralNetworkFuture_0000000000000nan_tr_0_FinalDenseLevel_0000000000000004_tr_0_FinalDenseUnit_0000000000000004_tr_0_0_dns_/Sigmoid:0', description="created by layer 'NeuralNetworkFuture_0000000000000nan_tr_0_FinalDenseLevel_0000000000000004_tr_0_FinalDenseUnit_0000000000000004_tr_0_0_dns_'")
# Model: "NeuralNetworkFuture_0000000000000nan_tr_0_nn_materialized"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  NeuralNetworkFuture_0000000000  [(None, 8)]         0           []
#  000nan_tr_0_InputLevel_0000000
#  000000000_tr_0_InputUnit_00000
#  00000000000_tr_0_0_inp (InputL
#  ayer)
#
#  NeuralNetworkFuture_0000000000  (None, 32)          0           ['NeuralNetworkFuture_00000000000
#  000nan_tr_0_DenseLevel_0000000                                  00nan_tr_0_InputLevel_00000000000
#  000000001_tr_0_DenseUnit_00000                                  00000_tr_0_InputUnit_000000000000
#  00000000001_tr_0_0_cat_ (Conca                                  0000_tr_0_0_inp[0][0]',
#  tenate)                                                          'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_InputLevel_00000000000
#                                                                  00000_tr_0_InputUnit_000000000000
#                                                                  0000_tr_0_0_inp[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_InputLevel_00000000000
#                                                                  00000_tr_0_InputUnit_000000000000
#                                                                  0000_tr_0_0_inp[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_InputLevel_00000000000
#                                                                  00000_tr_0_InputUnit_000000000000
#                                                                  0000_tr_0_0_inp[0][0]']
#
#  NeuralNetworkFuture_0000000000  (None, 32)          128         ['NeuralNetworkFuture_00000000000
#  000nan_tr_0_DenseLevel_0000000                                  00nan_tr_0_DenseLevel_00000000000
#  000000001_tr_0_DenseUnit_00000                                  00001_tr_0_DenseUnit_000000000000
#  00000000001_tr_0_0_btn_ (Batch                                  0001_tr_0_0_cat_[0][0]']
#  Normalization)
#
#  NeuralNetworkFuture_0000000000  (None, 3)           99          ['NeuralNetworkFuture_00000000000
#  000nan_tr_0_DenseLevel_0000000                                  00nan_tr_0_DenseLevel_00000000000
#  000000001_tr_0_DenseUnit_00000                                  00001_tr_0_DenseUnit_000000000000
#  00000000001_tr_0_0_dns_ (Dense                                  0001_tr_0_0_btn_[0][0]']
#  )
#
#  NeuralNetworkFuture_0000000000  (None, 22)          0           ['NeuralNetworkFuture_00000000000
#  000nan_tr_0_DenseLevel_0000000                                  00nan_tr_0_InputLevel_00000000000
#  000000002_tr_0_DenseUnit_00000                                  00000_tr_0_InputUnit_000000000000
#  00000000002_tr_0_1_cat_ (Conca                                  0000_tr_0_0_inp[0][0]',
#  tenate)                                                          'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00001_tr_0_DenseUnit_000000000000
#                                                                  0001_tr_0_0_dns_[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_InputLevel_00000000000
#                                                                  00000_tr_0_InputUnit_000000000000
#                                                                  0000_tr_0_0_inp[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00001_tr_0_DenseUnit_000000000000
#                                                                  0001_tr_0_0_dns_[0][0]']
#
#  NeuralNetworkFuture_0000000000  (None, 22)          88          ['NeuralNetworkFuture_00000000000
#  000nan_tr_0_DenseLevel_0000000                                  00nan_tr_0_DenseLevel_00000000000
#  000000002_tr_0_DenseUnit_00000                                  00002_tr_0_DenseUnit_000000000000
#  00000000002_tr_0_1_btn_ (Batch                                  0002_tr_0_1_cat_[0][0]']
#  Normalization)
#
#  NeuralNetworkFuture_0000000000  (None, 2)           46          ['NeuralNetworkFuture_00000000000
#  000nan_tr_0_DenseLevel_0000000                                  00nan_tr_0_DenseLevel_00000000000
#  000000002_tr_0_DenseUnit_00000                                  00002_tr_0_DenseUnit_000000000000
#  00000000002_tr_0_1_dns_ (Dense                                  0002_tr_0_1_btn_[0][0]']
#  )
#
#  NeuralNetworkFuture_0000000000  (None, 24)          0           ['NeuralNetworkFuture_00000000000
#  000nan_tr_0_DenseLevel_0000000                                  00nan_tr_0_DenseLevel_00000000000
#  000000002_tr_0_DenseUnit_00000                                  00002_tr_0_DenseUnit_000000000000
#  00000000002_tr_0_2_cat_ (Conca                                  0002_tr_0_1_dns_[0][0]',
#  tenate)                                                          'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_InputLevel_00000000000
#                                                                  00000_tr_0_InputUnit_000000000000
#                                                                  0000_tr_0_0_inp[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00001_tr_0_DenseUnit_000000000000
#                                                                  0001_tr_0_0_dns_[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_InputLevel_00000000000
#                                                                  00000_tr_0_InputUnit_000000000000
#                                                                  0000_tr_0_0_inp[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00001_tr_0_DenseUnit_000000000000
#                                                                  0001_tr_0_0_dns_[0][0]']
#
#  NeuralNetworkFuture_0000000000  (None, 24)          96          ['NeuralNetworkFuture_00000000000
#  000nan_tr_0_DenseLevel_0000000                                  00nan_tr_0_DenseLevel_00000000000
#  000000002_tr_0_DenseUnit_00000                                  00002_tr_0_DenseUnit_000000000000
#  00000000002_tr_0_2_btn_ (Batch                                  0002_tr_0_2_cat_[0][0]']
#  Normalization)
#
#  NeuralNetworkFuture_0000000000  (None, 2)           50          ['NeuralNetworkFuture_00000000000
#  000nan_tr_0_DenseLevel_0000000                                  00nan_tr_0_DenseLevel_00000000000
#  000000002_tr_0_DenseUnit_00000                                  00002_tr_0_DenseUnit_000000000000
#  00000000002_tr_0_2_dns_ (Dense                                  0002_tr_0_2_btn_[0][0]']
#  )
#
#  NeuralNetworkFuture_0000000000  (None, 22)          0           ['NeuralNetworkFuture_00000000000
#  000nan_tr_0_DenseLevel_0000000                                  00nan_tr_0_InputLevel_00000000000
#  000000002_tr_0_DenseUnit_00000                                  00000_tr_0_InputUnit_000000000000
#  00000000002_tr_0_0_cat_ (Conca                                  0000_tr_0_0_inp[0][0]',
#  tenate)                                                          'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00001_tr_0_DenseUnit_000000000000
#                                                                  0001_tr_0_0_dns_[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_InputLevel_00000000000
#                                                                  00000_tr_0_InputUnit_000000000000
#                                                                  0000_tr_0_0_inp[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00001_tr_0_DenseUnit_000000000000
#                                                                  0001_tr_0_0_dns_[0][0]']
#
#  NeuralNetworkFuture_0000000000  (None, 28)          0           ['NeuralNetworkFuture_00000000000
#  000nan_tr_0_DenseLevel_0000000                                  00nan_tr_0_DenseLevel_00000000000
#  000000002_tr_0_DenseUnit_00000                                  00002_tr_0_DenseUnit_000000000000
#  00000000002_tr_0_3_cat_ (Conca                                  0002_tr_0_2_dns_[0][0]',
#  tenate)                                                          'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00002_tr_0_DenseUnit_000000000000
#                                                                  0002_tr_0_1_dns_[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00002_tr_0_DenseUnit_000000000000
#                                                                  0002_tr_0_1_dns_[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_InputLevel_00000000000
#                                                                  00000_tr_0_InputUnit_000000000000
#                                                                  0000_tr_0_0_inp[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00001_tr_0_DenseUnit_000000000000
#                                                                  0001_tr_0_0_dns_[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_InputLevel_00000000000
#                                                                  00000_tr_0_InputUnit_000000000000
#                                                                  0000_tr_0_0_inp[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00001_tr_0_DenseUnit_000000000000
#                                                                  0001_tr_0_0_dns_[0][0]']
#
#  NeuralNetworkFuture_0000000000  (None, 22)          88          ['NeuralNetworkFuture_00000000000
#  000nan_tr_0_DenseLevel_0000000                                  00nan_tr_0_DenseLevel_00000000000
#  000000002_tr_0_DenseUnit_00000                                  00002_tr_0_DenseUnit_000000000000
#  00000000002_tr_0_0_btn_ (Batch                                  0002_tr_0_0_cat_[0][0]']
#  Normalization)
#
#  NeuralNetworkFuture_0000000000  (None, 28)          112         ['NeuralNetworkFuture_00000000000
#  000nan_tr_0_DenseLevel_0000000                                  00nan_tr_0_DenseLevel_00000000000
#  000000002_tr_0_DenseUnit_00000                                  00002_tr_0_DenseUnit_000000000000
#  00000000002_tr_0_3_btn_ (Batch                                  0002_tr_0_3_cat_[0][0]']
#  Normalization)
#
#  NeuralNetworkFuture_0000000000  (None, 4)           92          ['NeuralNetworkFuture_00000000000
#  000nan_tr_0_DenseLevel_0000000                                  00nan_tr_0_DenseLevel_00000000000
#  000000002_tr_0_DenseUnit_00000                                  00002_tr_0_DenseUnit_000000000000
#  00000000002_tr_0_0_dns_ (Dense                                  0002_tr_0_0_btn_[0][0]']
#  )
#
#  NeuralNetworkFuture_0000000000  (None, 1)           29          ['NeuralNetworkFuture_00000000000
#  000nan_tr_0_DenseLevel_0000000                                  00nan_tr_0_DenseLevel_00000000000
#  000000002_tr_0_DenseUnit_00000                                  00002_tr_0_DenseUnit_000000000000
#  00000000002_tr_0_3_dns_ (Dense                                  0002_tr_0_3_btn_[0][0]']
#  )
#
#  NeuralNetworkFuture_0000000000  (None, 37)          0           ['NeuralNetworkFuture_00000000000
#  000nan_tr_0_DenseLevel_0000000                                  00nan_tr_0_InputLevel_00000000000
#  000000003_tr_0_DenseUnit_00000                                  00000_tr_0_InputUnit_000000000000
#  00000000003_tr_0_1_cat_ (Conca                                  0000_tr_0_0_inp[0][0]',
#  tenate)                                                          'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00001_tr_0_DenseUnit_000000000000
#                                                                  0001_tr_0_0_dns_[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00002_tr_0_DenseUnit_000000000000
#                                                                  0002_tr_0_0_dns_[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00002_tr_0_DenseUnit_000000000000
#                                                                  0002_tr_0_2_dns_[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00002_tr_0_DenseUnit_000000000000
#                                                                  0002_tr_0_2_dns_[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_InputLevel_00000000000
#                                                                  00000_tr_0_InputUnit_000000000000
#                                                                  0000_tr_0_0_inp[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00001_tr_0_DenseUnit_000000000000
#                                                                  0001_tr_0_0_dns_[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00002_tr_0_DenseUnit_000000000000
#                                                                  0002_tr_0_0_dns_[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00002_tr_0_DenseUnit_000000000000
#                                                                  0002_tr_0_3_dns_[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00002_tr_0_DenseUnit_000000000000
#                                                                  0002_tr_0_1_dns_[0][0]']
#
#  NeuralNetworkFuture_0000000000  (None, 37)          148         ['NeuralNetworkFuture_00000000000
#  000nan_tr_0_DenseLevel_0000000                                  00nan_tr_0_DenseLevel_00000000000
#  000000003_tr_0_DenseUnit_00000                                  00003_tr_0_DenseUnit_000000000000
#  00000000003_tr_0_1_btn_ (Batch                                  0003_tr_0_1_cat_[0][0]']
#  Normalization)
#
#  NeuralNetworkFuture_0000000000  (None, 3)           114         ['NeuralNetworkFuture_00000000000
#  000nan_tr_0_DenseLevel_0000000                                  00nan_tr_0_DenseLevel_00000000000
#  000000003_tr_0_DenseUnit_00000                                  00003_tr_0_DenseUnit_000000000000
#  00000000003_tr_0_1_dns_ (Dense                                  0003_tr_0_1_btn_[0][0]']
#  )
#
#  NeuralNetworkFuture_0000000000  (None, 39)          0           ['NeuralNetworkFuture_00000000000
#  000nan_tr_0_DenseLevel_0000000                                  00nan_tr_0_InputLevel_00000000000
#  000000003_tr_0_DenseUnit_00000                                  00000_tr_0_InputUnit_000000000000
#  00000000003_tr_0_0_cat_ (Conca                                  0000_tr_0_0_inp[0][0]',
#  tenate)                                                          'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00001_tr_0_DenseUnit_000000000000
#                                                                  0001_tr_0_0_dns_[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00002_tr_0_DenseUnit_000000000000
#                                                                  0002_tr_0_1_dns_[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00002_tr_0_DenseUnit_000000000000
#                                                                  0002_tr_0_0_dns_[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00002_tr_0_DenseUnit_000000000000
#                                                                  0002_tr_0_0_dns_[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_InputLevel_00000000000
#                                                                  00000_tr_0_InputUnit_000000000000
#                                                                  0000_tr_0_0_inp[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00001_tr_0_DenseUnit_000000000000
#                                                                  0001_tr_0_0_dns_[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00002_tr_0_DenseUnit_000000000000
#                                                                  0002_tr_0_1_dns_[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00002_tr_0_DenseUnit_000000000000
#                                                                  0002_tr_0_0_dns_[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00002_tr_0_DenseUnit_000000000000
#                                                                  0002_tr_0_3_dns_[0][0]']
#
#  NeuralNetworkFuture_0000000000  (None, 45)          0           ['NeuralNetworkFuture_00000000000
#  000nan_tr_0_DenseLevel_0000000                                  00nan_tr_0_DenseLevel_00000000000
#  000000003_tr_0_DenseUnit_00000                                  00003_tr_0_DenseUnit_000000000000
#  00000000003_tr_0_2_cat_ (Conca                                  0003_tr_0_1_dns_[0][0]',
#  tenate)                                                          'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00003_tr_0_DenseUnit_000000000000
#                                                                  0003_tr_0_1_dns_[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_InputLevel_00000000000
#                                                                  00000_tr_0_InputUnit_000000000000
#                                                                  0000_tr_0_0_inp[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00001_tr_0_DenseUnit_000000000000
#                                                                  0001_tr_0_0_dns_[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00002_tr_0_DenseUnit_000000000000
#                                                                  0002_tr_0_1_dns_[0][0]',
#                                                                   'NeuralNetworkFuture_00000000000
#                                                                  00nan_tr_0_DenseLevel_00000000000
#                                                                  00002_tr_0_DenseUnit_000000000000
#                                                                  0002_tr_0_3_dns_[0][0]',
# ...
# materialize:_NeuralNetworkFuture_0000000000000nan_tr_1_DenseLevel_0000000000000003_tr_1_DenseUnit_0000000000000003_tr_1_1 called
# materialized network layers
# [<KerasTensor: shape=(None, 8) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_1_InputLevel_0000000000000000_tr_1_InputUnit_0000000000000000_tr_1_0_inp')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_1_DenseLevel_0000000000000001_tr_1_DenseUnit_0000000000000001_tr_1_2_dns_')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_1_DenseLevel_0000000000000001_tr_1_DenseUnit_0000000000000001_tr_1_3_dns_')>, <KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_1_DenseLevel_0000000000000002_tr_1_DenseUnit_0000000000000002_tr_1_0_dns_')>, <KerasTensor: shape=(None, 8) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_1_InputLevel_0000000000000000_tr_1_InputUnit_0000000000000000_tr_1_0_inp')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_1_DenseLevel_0000000000000001_tr_1_DenseUnit_0000000000000001_tr_1_2_dns_')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_1_DenseLevel_0000000000000001_tr_1_DenseUnit_0000000000000001_tr_1_0_dns_')>, <KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_1_DenseLevel_0000000000000002_tr_1_DenseUnit_0000000000000002_tr_1_0_dns_')>]
# materialize:_NeuralNetworkFuture_0000000000000nan_tr_1_DenseLevel_0000000000000003_tr_1_DenseUnit_0000000000000003_tr_1_2 called
# materialized network layers
# [<KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_1_DenseLevel_0000000000000003_tr_1_DenseUnit_0000000000000003_tr_1_1_dns_')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_1_DenseLevel_0000000000000003_tr_1_DenseUnit_0000000000000003_tr_1_1_dns_')>, <KerasTensor: shape=(None, 8) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_1_InputLevel_0000000000000000_tr_1_InputUnit_0000000000000000_tr_1_0_inp')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_1_DenseLevel_0000000000000001_tr_1_DenseUnit_0000000000000001_tr_1_2_dns_')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_1_DenseLevel_0000000000000001_tr_1_DenseUnit_0000000000000001_tr_1_2_dns_')>, <KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_1_DenseLevel_0000000000000002_tr_1_DenseUnit_0000000000000002_tr_1_0_dns_')>, <KerasTensor: shape=(None, 8) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_1_InputLevel_0000000000000000_tr_1_InputUnit_0000000000000000_tr_1_0_inp')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_1_DenseLevel_0000000000000001_tr_1_DenseUnit_0000000000000001_tr_1_0_dns_')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_1_DenseLevel_0000000000000001_tr_1_DenseUnit_0000000000000001_tr_1_3_dns_')>, <KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_1_DenseLevel_0000000000000002_tr_1_DenseUnit_0000000000000002_tr_1_0_dns_')>]
# materialize:_NeuralNetworkFuture_0000000000000nan_tr_1_DenseLevel_0000000000000003_tr_1_DenseUnit_0000000000000003_tr_1_3 called
# materialized network layers
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_1_DenseLevel_0000000000000003_tr_1_DenseUnit_0000000000000003_tr_1_2_dns_')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_1_DenseLevel_0000000000000003_tr_1_DenseUnit_0000000000000003_tr_1_1_dns_')>, <KerasTensor: shape=(None, 3) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_1_DenseLevel_0000000000000003_tr_1_DenseUnit_0000000000000003_tr_1_1_dns_')>, <KerasTensor: shape=(None, 8) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_1_InputLevel_0000000000000000_tr_1_InputUnit_0000000000000000_tr_1_0_inp')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_1_DenseLevel_0000000000000001_tr_1_DenseUnit_0000000000000001_tr_1_0_dns_')>, <KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_1_DenseLevel_0000000000000001_tr_1_DenseUnit_0000000000000001_tr_1_1_dns_')>, <KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_1_DenseLevel_0000000000000002_tr_1_DenseUnit_0000000000000002_tr_1_0_dns_')>, <KerasTensor: shape=(None, 8) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_1_InputLevel_0000000000000000_tr_1_InputUnit_0000000000000000_tr_1_0_inp')>, <KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_1_DenseLevel_0000000000000001_tr_1_DenseUnit_0000000000000001_tr_1_1_dns_')>, <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_1_DenseLevel_0000000000000001_tr_1_DenseUnit_0000000000000001_tr_1_0_dns_')>, <KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'NeuralNetworkFuture_0000000000000nan_tr_1_DenseLevel_0000000000000002_tr_1_DenseUnit_0000000000000002_tr_1_0_dns_')>]
# {'1': <class 'cerebros.units.units.DenseUnit'>}
# debug: meta_level_number
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [4], line 52
#       5 meta_trial_number = str(int(np.random.random() * 10 ** 12))
#       8 cerebros_automl = SimpleCerebrosRandomSearch(
#       9     unit_type=DenseUnit,
#      10     input_shapes=INPUT_SHAPES,
#    (...)
#      50     batch_size=batch_size,
#      51     meta_trial_number=meta_trial_number)
# ---> 52 val_binary_accuracy = cerebros_automl.run_random_search()
#
# File ~/cerebros-core-algorithm-alpha/cerebros/simplecerebrosrandomsearch/simple_cerebros_random_search.py:514, in SimpleCerebrosRandomSearch.run_random_search(self)
#     510 lock = Lock()
#     511 for i in np.arange(
#     512         self.number_of_tries_per_architecture_moity):
#     513     processes.append(
# --> 514         Process(target=self.run_moity_permutations(spec=spec, subtrial_number=subtrial_number, lock=lock)))
#     515     subtrial_number += 1
#     516     self.seed += 1
#
# File ~/cerebros-core-algorithm-alpha/cerebros/simplecerebrosrandomsearch/simple_cerebros_random_search.py:465, in SimpleCerebrosRandomSearch.run_moity_permutations(self, spec, subtrial_number, lock)
#     436 #with STRATEGY.scope():
#     437 nnf = NeuralNetworkFuture(
#     438     input_shapes=self.input_shapes,
#     439     output_shapes=self.output_shapes,
#    (...)
#     463     model_graph_file=model_graph_file
#     464     )
# --> 465 nnf.materialize()
#     466 nnf.compile_neural_network()
#     467 neural_network = nnf.materialized_neural_network
#
# File ~/cerebros-core-algorithm-alpha/cerebros/neuralnetworkfuture/neural_network_future.py:284, in NeuralNetworkFuture.materialize(self)
#     281 self.util_set_predecessor_connectivity_metadata()
#     283 for level in self.levels_unmaterialized:
# --> 284     level.materialize()
#     285 if len(self.levels_unmaterialized[0].parallel_units) > 1:
#     286     materialized_neural_network_inputs =\
#     287         [unit_0.neural_network_layer
#     288          for unit_0 in self.levels_unmaterialized[0].parallel_units]
#
# File ~/cerebros-core-algorithm-alpha/cerebros/levels/levels.py:557, in DenseLevel.materialize(self)
#     555 self.parse_units()
#     556 self.set_connectivity_future_prototype()
# --> 557 self.parse_meta_predecessor_connectivity()
#     558 self.set_successor_levels()
#     559 self.detect_successor_connectivity_errors()
#
# File ~/cerebros-core-algorithm-alpha/cerebros/levels/levels.py:542, in DenseLevel.parse_meta_predecessor_connectivity(self)
#     532     meta_level_number =\
#     533         jnp.concatenate(
#     534             [meta_level_number,
#     535              unit_0.meta_predecessor_connectivity_level_number],
#     536             dtype=jnp.int32)
#     537     meta_unit_id =\
#     538         jnp.concatenate(
#     539             [meta_unit_id,
#     540              unit_0.meta_predecessor_connectivity_unit_id],
#     541             dtype=jnp.int32)
# --> 542 check_unique_units = jnp.column_stack(
#     543     [meta_level_number, meta_unit_id])
#     544 unique_units = jnp.unique(check_unique_units, axis=0)
#     546 self.meta_predecessor_connectivity_level_number = unique_units[:, 0]
#
# File ~/.local/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py:1842, in column_stack(tup)
#    1840   arrs = jax.vmap(lambda x: atleast_2d(x).T)(tup) if tup.ndim < 3 else tup
#    1841 else:
# -> 1842   arrs = [atleast_2d(arr).T if arr.ndim < 2 else arr for arr in map(asarray, tup)]
#    1843 return concatenate(arrs, 1)
#
# File ~/.local/lib/python3.8/site-packages/jax/_src/numpy/lax_numpy.py:1842, in <listcomp>(.0)
#    1840   arrs = jax.vmap(lambda x: atleast_2d(x).T)(tup) if tup.ndim < 3 else tup
#    1841 else:
# -> 1842   arrs = [atleast_2d(arr).T if arr.ndim < 2 else arr for arr in map(asarray, tup)]
#    1843 return concatenate(arrs, 1)
#
#     [... skipping hidden 1 frame]
#
# File ~/.local/lib/python3.8/site-packages/jax/_src/api.py:622, in _cpp_jit.<locals>.cache_miss(*args, **kwargs)
#     619 execute = None
#     620 if isinstance(top_trace, core.EvalTrace) and not (
#     621     jax.config.jax_debug_nans or jax.config.jax_debug_infs):
# --> 622   execute = dispatch._xla_call_impl_lazy(fun_, *tracers, **params)
#     623   out_flat = call_bind_continuation(execute(*args_flat))
#     624 else:
#
# File ~/.local/lib/python3.8/site-packages/jax/_src/dispatch.py:241, in _xla_call_impl_lazy(***failed resolving arguments***)
#     239     raise NotImplementedError('Dynamic shapes do not work with Array.')
#     240   arg_specs = [(None, getattr(x, '_device', None)) for x in args]
# --> 241 return xla_callable(fun, device, backend, name, donated_invars, keep_unused,
#     242                     *arg_specs)
#
# File ~/.local/lib/python3.8/site-packages/jax/linear_util.py:303, in cache.<locals>.memoized_fun(fun, *args)
#     301   fun.populate_stores(stores)
#     302 else:
# --> 303   ans = call(fun, *args)
#     304   cache[key] = (ans, fun.stores)
#     306 return ans
#
# File ~/.local/lib/python3.8/site-packages/jax/_src/dispatch.py:359, in _xla_callable_uncached(fun, device, backend, name, donated_invars, keep_unused, *arg_specs)
#     356 if config.jax_array:
#     357   computation = sharded_lowering(fun, device, backend, name, donated_invars,
#     358                                  False, keep_unused, *arg_specs)
# --> 359   return computation.compile(_allow_propagation_to_outputs=True).unsafe_call
#     360 else:
#     361   return lower_xla_callable(fun, device, backend, name, donated_invars, False,
#     362                             keep_unused, *arg_specs).compile().unsafe_call
#
# File ~/.local/lib/python3.8/site-packages/jax/interpreters/pxla.py:3202, in MeshComputation.compile(self, _allow_propagation_to_outputs, _allow_compile_replicated)
#    3198 def compile(self,
#    3199             _allow_propagation_to_outputs : bool = False,
#    3200             _allow_compile_replicated : bool = True) -> MeshExecutable:
#    3201   if self._executable is None:
# -> 3202     executable = self._compile_unloaded(
#    3203         _allow_propagation_to_outputs, _allow_compile_replicated)
#    3204     if isinstance(executable, UnloadedMeshExecutable):
#    3205       executable = executable.load()
#
# File ~/.local/lib/python3.8/site-packages/jax/interpreters/pxla.py:3170, in MeshComputation._compile_unloaded(self, _allow_propagation_to_outputs, _allow_compile_replicated)
#    3168   return MeshExecutable.from_trivial_jaxpr(**self.compile_args)
#    3169 else:
# -> 3170   return UnloadedMeshExecutable.from_hlo(
#    3171       self._name,
#    3172       self._hlo,
#    3173       **self.compile_args,
#    3174       _allow_propagation_to_outputs=_allow_propagation_to_outputs,
#    3175       _allow_compile_replicated=_allow_compile_replicated)
#
# File ~/.local/lib/python3.8/site-packages/jax/interpreters/pxla.py:3439, in UnloadedMeshExecutable.from_hlo(name, computation, mesh, global_in_avals, global_out_avals, in_shardings, out_shardings, spmd_lowering, tuple_args, in_is_global, auto_spmd_lowering, _allow_propagation_to_outputs, _allow_compile_replicated, unordered_effects, ordered_effects, host_callbacks, keepalive, kept_var_idx, backend, device_assignment, committed, pmap_nreps)
#    3435 else:
#    3436   with dispatch.log_elapsed_time(f"Finished XLA compilation of {name} "
#    3437                                  "in {elapsed_time} sec",
#    3438                                  event=dispatch.BACKEND_COMPILE_EVENT):
# -> 3439     xla_executable = dispatch.compile_or_get_cached(
#    3440         backend, computation, compile_options, host_callbacks)
#    3442   if auto_spmd_lowering:
#    3443     assert mesh is not None
#
# File ~/.local/lib/python3.8/site-packages/jax/_src/dispatch.py:1079, in compile_or_get_cached(backend, computation, compile_options, host_callbacks)
#    1075     _cache_write(serialized_computation, compile_time, module_name,
#    1076                  compile_options, backend, compiled)
#    1077     return compiled
# -> 1079 return backend_compile(backend, serialized_computation, compile_options,
#    1080                        host_callbacks)
#
# File ~/.local/lib/python3.8/site-packages/jax/_src/profiler.py:314, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     311 @wraps(func)
#     312 def wrapper(*args, **kwargs):
#     313   with TraceAnnotation(name, **decorator_kwargs):
# --> 314     return func(*args, **kwargs)
#     315   return wrapper
#
# File ~/.local/lib/python3.8/site-packages/jax/_src/dispatch.py:1014, in backend_compile(backend, built_c, options, host_callbacks)
#    1009   return backend.compile(built_c, compile_options=options,
#    1010                          host_callbacks=host_callbacks)
#    1011 # Some backends don't have `host_callbacks` option yet
#    1012 # TODO(sharadmv): remove this fallback when all backends allow `compile`
#    1013 # to take in `host_callbacks`
# -> 1014 return backend.compile(built_c, compile_options=options)
#
# KeyboardInterrupt:

# %%
print(val_binary_accuracy)
# Out:
# 1
